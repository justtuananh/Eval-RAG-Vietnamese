# %%
# %pip install --upgrade --quiet  lark
# %pip install --upgrade --quiet  langchain-chroma

# %%
from qdrant_client.http.models import Distance, VectorParams
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.document_loaders import TextLoader
from langchain.text_splitter import MarkdownHeaderTextSplitter
from langchain.retrievers.self_query.base import SelfQueryRetriever
from langchain.vectorstores import Chroma
from langchain.text_splitter import RecursiveCharacterTextSplitter, CharacterTextSplitter
from langchain.document_loaders import TextLoader
from langchain_community.embeddings.huggingface import HuggingFaceEmbeddings
from langchain.retrievers import ParentDocumentRetriever
from langchain.storage import InMemoryStore
from langchain.docstore.document import Document
from typing import List, Dict
from langchain.vectorstores import Redis
from langchain.chains import RetrievalQA
from langchain_groq import ChatGroq
from langchain.chains.query_constructor.base import (
    get_query_constructor_prompt,
    load_query_constructor_runnable,
    AttributeInfo)
from dotenv import load_dotenv
load_dotenv()
import os

# %%
HF_EMBEDDING = HuggingFaceEmbeddings(model_name="keepitreal/vietnamese-sbert")
llm = ChatGroq(model_name="llama3-70b-8192", temperature=0.1,api_key= os.getenv('llm_api_1'))
# Out:
# /home/justtuananh/miniconda3/lib/python3.12/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /home/justtuananh/miniconda3/lib/python3.12/site-packages/torch/cuda/__init__.py:118: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# /home/justtuananh/miniconda3/lib/python3.12/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
# Function to load and chunk data from a folder
def load_and_chunk_data(data_path):
    docs = []
    # Load all .txt files from the specified folder
    for filename in os.listdir(data_path):
        if filename.endswith('.txt'):
            file_path = os.path.join(data_path, filename)
            loader = TextLoader(file_path, encoding='utf-8')
            docs.extend(loader.load())

    # Define headers to split on for Markdown splitting
    headers_to_split_on = [
        ("#", "Header 1"),
        ("##", "Header 2"),
        ("###", "Header 3"),
    ]

    # Initialize Markdown splitter
    markdown_splitter = MarkdownHeaderTextSplitter(
        headers_to_split_on=headers_to_split_on, strip_headers=False
    )

    chunk_size = 512
    chunk_overlap = 0

    # Initialize character-based splitter
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size, chunk_overlap=chunk_overlap
    )

    chunked_docs = []

    # Process each document
    for doc in docs:
        # Split document by Markdown headers
        md_header_splits = markdown_splitter.split_text(doc.page_content)

        # Further split the Markdown header splits into smaller chunks
        chunked_docs.extend(text_splitter.split_documents(md_header_splits))

    return chunked_docs


data_path = '/home/justtuananh/AI4TUAN/DOAN2024/eval_rag_vietnamese/thongtintuyensinh'
chunked_data = load_and_chunk_data(data_path)

# %%
vectorstore = Chroma.from_documents(chunked_data, HF_EMBEDDING, persist_directory="./data_chroma")

# vectorstore = Chroma(persist_directory="./data_chroma" ,embedding_function=HF_EMBEDDING)
# retriever =vectorstore.as_retriever()

# %%
def build_index_schema(documents: List[Document]) -> Dict:
    schema = {"text": []}
    for doc in documents:
        for key in doc.metadata:
            name_dict = {"name": f"{key}"}
            if name_dict not in schema["text"]:
                schema["text"].append(name_dict)
    return schema

index_schema = build_index_schema(chunked_data)
print(index_schema)
# Out:
# {'text': [{'name': 'Header 1'}, {'name': 'Header 2'}, {'name': 'Header 3'}]}

# %%
retriever = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=vectorstore.as_retriever(search_kwargs={"k": 20}),
    return_source_documents=True
)

# %%
# add self-query
from langchain.chains.query_constructor.base import (
    get_query_constructor_prompt,
    load_query_constructor_runnable,
    AttributeInfo)

document_content_description = "The document contains introductory information about the admissions details of the Military Technical Academy."

headers_to_split_on = [
        ("#", "Header 1"),
        ("##", "Header 2"),
        ("###", "Header 3"),
    ]


def generate_metadata_desc(field_name: str, header_info: List[tuple], qa_retriever: RetrievalQA) -> str:
    query = f"""
    Given a list of tuples indicating all possible metadata fields for this article,
    provide a very brief description (15 words or less) of the specified field,
    including its position in the hierarchy of headers (Header 1, Header 2, Header 3, etc.).

    all fields {header_info}
    specified field: {field_name}
    """

    return qa_retriever({"query": query})["result"]

def build_metadata_field_info(schema: Dict, header_info: List[tuple], qa_retriever: RetrievalQA) -> List[AttributeInfo]:
    filter_instructions = \
        "ALWAYS filter with one or more CONTAINS comparators, and use the OR operator to check ALL other fields."\
        "if the value of this field contains a word or phrase that is very similar to a word or phrase in the query, " \
        "filter for the exact string from the value rather than the query."
    filter_h1 = \
        "if the query contains a misspelling or an alternate spelling of this name, "\
        "filter for the value of this field rather than the name in the query."\
        "the h1-level filter should ALWAYS be combined with subsection filters using an AND operator. \n"
    filter_exclusion = \
        " NEVER filter this field on the value of 'Header 1'."
    attr_info_list = []
    for field in schema["text"]:
        desc = generate_metadata_desc(field["name"], header_info, qa_retriever) + filter_instructions
        if field["name"] == "Header 1":
            new_attr = AttributeInfo(
                name=field["name"],
                description = filter_h1 + desc,
                type="string"
            )
        else:
            new_attr = AttributeInfo(
                name=field["name"],
                description = desc + filter_exclusion,
                type="string"
            )
        attr_info_list.append(new_attr)
    return attr_info_list

metadata_field_info = build_metadata_field_info(index_schema, headers_to_split_on, retriever)
# Out:
# /tmp/ipykernel_88527/2234936660.py:26: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 0.3.0. Use invoke instead.
#   return qa_retriever({"query": query})["result"]

# %%
metadata_field_info
# Out:
# [AttributeInfo(name='Header 1', description='if the query contains a misspelling or an alternate spelling of this name, filter for the value of this field rather than the name in the query.the h1-level filter should ALWAYS be combined with subsection filters using an AND operator. \n"Introduction to the Military Technical Academy, top-level header."ALWAYS filter with one or more CONTAINS comparators, and use the OR operator to check ALL other fields.if the value of this field contains a word or phrase that is very similar to a word or phrase in the query, filter for the exact string from the value rather than the query.', type='string'),
#  AttributeInfo(name='Header 2', description='"Method of recruitment, 2024 recruitment process details (Header 2)"ALWAYS filter with one or more CONTAINS comparators, and use the OR operator to check ALL other fields.if the value of this field contains a word or phrase that is very similar to a word or phrase in the query, filter for the exact string from the value rather than the query. NEVER filter this field on the value of \'Header 1\'.', type='string'),
#  AttributeInfo(name='Header 3', description='Here is the brief description of the specified field:\n\n"Header 3: Sub-subheading, third-level header in the article hierarchy."ALWAYS filter with one or more CONTAINS comparators, and use the OR operator to check ALL other fields.if the value of this field contains a word or phrase that is very similar to a word or phrase in the query, filter for the exact string from the value rather than the query. NEVER filter this field on the value of \'Header 1\'.', type='string')]

# %%
retriever = SelfQueryRetriever.from_llm(
    llm, vectorstore, document_content_description, metadata_field_info, verbose=True
)
retriever.invoke("điểm chuẩn thi vào học viện năm 2024")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.12/site-packages/lark/parsers/lalr_parser_state.py:77, in ParserState.feed_token(self, token, is_end)
#      76 try:
# ---> 77     action, arg = states[state][token.type]
#      78 except KeyError:
#
# KeyError: '$END'
#
# During handling of the above exception, another exception occurred:
#
# UnexpectedToken                           Traceback (most recent call last)
# File ~/miniconda3/lib/python3.12/site-packages/langchain/chains/query_constructor/base.py:56, in StructuredQueryOutputParser.parse(self, text)
#      55 else:
# ---> 56     parsed["filter"] = self.ast_parse(parsed["filter"])
#      57 if not parsed.get("limit"):
#
# File ~/miniconda3/lib/python3.12/site-packages/lark/lark.py:655, in Lark.parse(self, text, start, on_error)
#     638 """Parse the given text, according to the options provided.
#     639
#     640 Parameters:
#    (...)
#     653
#     654 """
# --> 655 return self.parser.parse(text, start=start, on_error=on_error)
#
# File ~/miniconda3/lib/python3.12/site-packages/lark/parser_frontends.py:104, in ParsingFrontend.parse(self, text, start, on_error)
#     103 stream = self._make_lexer_thread(text)
# --> 104 return self.parser.parse(stream, chosen_start, **kw)
#
# File ~/miniconda3/lib/python3.12/site-packages/lark/parsers/lalr_parser.py:42, in LALR_Parser.parse(self, lexer, start, on_error)
#      41 try:
# ---> 42     return self.parser.parse(lexer, start)
#      43 except UnexpectedInput as e:
#
# File ~/miniconda3/lib/python3.12/site-packages/lark/parsers/lalr_parser.py:88, in _Parser.parse(self, lexer, start, value_stack, state_stack, start_interactive)
#      87     return InteractiveParser(self, parser_state, parser_state.lexer)
# ---> 88 return self.parse_from_state(parser_state)
#
# File ~/miniconda3/lib/python3.12/site-packages/lark/parsers/lalr_parser.py:111, in _Parser.parse_from_state(self, state, last_token)
#     110         pass
# --> 111     raise e
#     112 except Exception as e:
#
# File ~/miniconda3/lib/python3.12/site-packages/lark/parsers/lalr_parser.py:105, in _Parser.parse_from_state(self, state, last_token)
#     104     end_token = Token.new_borrow_pos('$END', '', token) if token else Token('$END', '', 0, 1, 1)
# --> 105     return state.feed_token(end_token, True)
#     106 except UnexpectedInput as e:
#
# File ~/miniconda3/lib/python3.12/site-packages/lark/parsers/lalr_parser_state.py:80, in ParserState.feed_token(self, token, is_end)
#      79     expected = {s for s in states[state].keys() if s.isupper()}
# ---> 80     raise UnexpectedToken(token, expected, state=self, interactive_parser=None)
#      82 assert arg != end_state
#
# UnexpectedToken: Unexpected token Token('$END', '') at line 1, column 20953.
# Expected one of:
# 	* LPAR
#
#
# During handling of the above exception, another exception occurred:
#
# OutputParserException                     Traceback (most recent call last)
# Cell In[9], line 4
#       1 retriever = SelfQueryRetriever.from_llm(
#       2     llm, vectorstore, document_content_description, metadata_field_info, verbose=True
#       3 )
# ----> 4 retriever.invoke("điểm chuẩn thi vào học viện năm 2024")
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain_core/retrievers.py:253, in BaseRetriever.invoke(self, input, config, **kwargs)
#     251 except Exception as e:
#     252     run_manager.on_retriever_error(e)
# --> 253     raise e
#     254 else:
#     255     run_manager.on_retriever_end(
#     256         result,
#     257     )
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain_core/retrievers.py:246, in BaseRetriever.invoke(self, input, config, **kwargs)
#     244 _kwargs = kwargs if self._expects_other_args else {}
#     245 if self._new_arg_supported:
# --> 246     result = self._get_relevant_documents(
#     247         input, run_manager=run_manager, **_kwargs
#     248     )
#     249 else:
#     250     result = self._get_relevant_documents(input, **_kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain/retrievers/self_query/base.py:217, in SelfQueryRetriever._get_relevant_documents(self, query, run_manager)
#     206 def _get_relevant_documents(
#     207     self, query: str, *, run_manager: CallbackManagerForRetrieverRun
#     208 ) -> List[Document]:
#     209     """Get documents relevant for a query.
#     210
#     211     Args:
#    (...)
#     215         List of relevant documents
#     216     """
# --> 217     structured_query = self.query_constructor.invoke(
#     218         {"query": query}, config={"callbacks": run_manager.get_child()}
#     219     )
#     220     if self.verbose:
#     221         logger.info(f"Generated Query: {structured_query}")
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain_core/runnables/base.py:5092, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5086 def invoke(
#    5087     self,
#    5088     input: Input,
#    5089     config: Optional[RunnableConfig] = None,
#    5090     **kwargs: Optional[Any],
#    5091 ) -> Output:
# -> 5092     return self.bound.invoke(
#    5093         input,
#    5094         self._merge_configs(config),
#    5095         **{**self.kwargs, **kwargs},
#    5096     )
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain_core/runnables/base.py:2878, in RunnableSequence.invoke(self, input, config, **kwargs)
#    2876             input = context.run(step.invoke, input, config, **kwargs)
#    2877         else:
# -> 2878             input = context.run(step.invoke, input, config)
#    2879 # finish the root run
#    2880 except BaseException as e:
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain_core/output_parsers/base.py:183, in BaseOutputParser.invoke(self, input, config)
#     179 def invoke(
#     180     self, input: Union[str, BaseMessage], config: Optional[RunnableConfig] = None
#     181 ) -> T:
#     182     if isinstance(input, BaseMessage):
# --> 183         return self._call_with_config(
#     184             lambda inner_input: self.parse_result(
#     185                 [ChatGeneration(message=inner_input)]
#     186             ),
#     187             input,
#     188             config,
#     189             run_type="parser",
#     190         )
#     191     else:
#     192         return self._call_with_config(
#     193             lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     194             input,
#     195             config,
#     196             run_type="parser",
#     197         )
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain_core/runnables/base.py:1785, in Runnable._call_with_config(self, func, input, config, run_type, **kwargs)
#    1781     context = copy_context()
#    1782     context.run(_set_config_context, child_config)
#    1783     output = cast(
#    1784         Output,
# -> 1785         context.run(
#    1786             call_func_with_variable_args,  # type: ignore[arg-type]
#    1787             func,  # type: ignore[arg-type]
#    1788             input,  # type: ignore[arg-type]
#    1789             config,
#    1790             run_manager,
#    1791             **kwargs,
#    1792         ),
#    1793     )
#    1794 except BaseException as e:
#    1795     run_manager.on_chain_error(e)
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain_core/runnables/config.py:398, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     396 if run_manager is not None and accepts_run_manager(func):
#     397     kwargs["run_manager"] = run_manager
# --> 398 return func(input, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain_core/output_parsers/base.py:184, in BaseOutputParser.invoke.<locals>.<lambda>(inner_input)
#     179 def invoke(
#     180     self, input: Union[str, BaseMessage], config: Optional[RunnableConfig] = None
#     181 ) -> T:
#     182     if isinstance(input, BaseMessage):
#     183         return self._call_with_config(
# --> 184             lambda inner_input: self.parse_result(
#     185                 [ChatGeneration(message=inner_input)]
#     186             ),
#     187             input,
#     188             config,
#     189             run_type="parser",
#     190         )
#     191     else:
#     192         return self._call_with_config(
#     193             lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     194             input,
#     195             config,
#     196             run_type="parser",
#     197         )
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain_core/output_parsers/base.py:237, in BaseOutputParser.parse_result(self, result, partial)
#     222 def parse_result(self, result: List[Generation], *, partial: bool = False) -> T:
#     223     """Parse a list of candidate model Generations into a specific format.
#     224
#     225     The return value is parsed from only the first Generation in the result, which
#    (...)
#     235         Structured output.
#     236     """
# --> 237     return self.parse(result[0].text)
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain/chains/query_constructor/base.py:63, in StructuredQueryOutputParser.parse(self, text)
#      59     return StructuredQuery(
#      60         **{k: v for k, v in parsed.items() if k in allowed_keys}
#      61     )
#      62 except Exception as e:
# ---> 63     raise OutputParserException(
#      64         f"Parsing text\n{text}\n raised following error:\n{e}"
#      65     )
#
# OutputParserException: Parsing text
# ```json
# {
#     "query": "điểm chuẩn thi vào học viện năm 2024",
#     "filter": "or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(or(o ...
#  raised following error:
# Unexpected token Token('$END', '') at line 1, column 20953.
# Expected one of:
# 	* LPAR

# %%
examples = [
    (
        "What is the admission quota for male candidates from the Northern region for the Military Technical Academy in 2024?",
        {"query": "admission quota, Military Technical Academy, 2024, male candidates from the Northern region",
         "filter": 'and(contain("Header 1", "ADMISSION INFORMATION FOR THE MILITARY TECHNICAL ACADEMY IN 2024"), or(contain("Header 2", "Admission quota"), '
                   'contain("Header 3", "Admission quota")))'}
    ),
    (
        "What are the admission methods at the Military Technical Academy?",
        {"query": "admission methods, Military Technical Academy",
         "filter": 'and(contain("Header 1", "ADMISSION INFORMATION FOR THE MILITARY TECHNICAL ACADEMY IN 2024"), or(contain("Header 2", "Admission methods"), '
                   'contain("Header 3", "Method 1: Direct admission"), contain("Header 3", "Method 2: Priority admission")))'}
    ),
    (
        "What was the admission score for the academy in 2023?",
        {"query": "admission score, 2023",
         "filter": 'and(contain("Header 1", "Admission information for 2021, 2022, 2023 of the Military Technical Academy"), or(contain("Header 2", "Admission scores for 2021, 2022, 2023"), '
                   'contain("Header 2", "Scores for 2023 of the academy"), contain("Header 2", "Cut-off scores for 2023")))'}
    )
]

# %%
prompt = get_query_constructor_prompt(
    document_content_description,
    metadata_field_info,
    examples=examples
)
result = prompt.format(query="{query}") 
result
# Out:
# 'Your goal is to structure the user\'s query to match the request schema provided below.\n\n<< Structured Request Schema >>\nWhen responding use a markdown code snippet with a JSON object formatted in the following schema:\n\n```json\n{\n    "query": string \\ text string to compare to document contents\n    "filter": string \\ logical condition statement for filtering documents\n}\n```\n\nThe query string should contain only text that is expected to match the contents of documents. Any conditions in the filter should not be mentioned in the query as well.\n\nA logical condition statement is composed of one or more comparison and logical operation statements.\n\nA comparison statement takes the form: `comp(attr, val)`:\n- `comp` (eq | ne | gt | gte | lt | lte | contain | like | in | nin): comparator\n- `attr` (string):  name of attribute to apply the comparison to\n- `val` (string): is the comparison value\n\nA logical operation statement takes the form `op(statement1, statement2, ...)`:\n- `op` (and | or | not): logical operator\n- `statement1`, `statement2`, ... (comparison statements or logical operation statements): one or more statements to apply the operation to\n\nMake sure that you only use the comparators and logical operators listed above and no others.\nMake sure that filters only refer to attributes that exist in the data source.\nMake sure that filters only use the attributed names with its function names if there are functions applied on them.\nMake sure that filters only use format `YYYY-MM-DD` when handling date data typed values.\nMake sure that filters take into account the descriptions of attributes and only make comparisons that are feasible given the type of data being stored.\nMake sure that filters are only used as needed. If there are no filters that should be applied return "NO_FILTER" for the filter value.\n\n<< Data Source >>\n```json\n{\n    "content": "The document contains introductory information about the admissions details of the Military Technical Academy.",\n    "attributes": {\n    "Header 1": {\n        "description": "if the query contains a misspelling or an alternate spelling of this name, filter for the value of this field rather than the name in the query.the h1-level filter should ALWAYS be combined with subsection filters using an AND operator. \\nHere is the brief description of the specified field:\\n\\n**Header 1**: Main topic or title of the article (Top-level header).ALWAYS filter with one or more CONTAINS comparators, and use the OR operator to check ALL other fields.if the value of this field contains a word or phrase that is very similar to a word or phrase in the query, filter for the exact string from the value rather than the query.",\n        "type": "string"\n    },\n    "Header 2": {\n        "description": "Here is the brief description of the specified field:\\n\\n**Header 2**: Subheading, secondary topic, or section title (Level 2).ALWAYS filter with one or more CONTAINS comparators, and use the OR operator to check ALL other fields.if the value of this field contains a word or phrase that is very similar to a word or phrase in the query, filter for the exact string from the value rather than the query. NEVER filter this field on the value of \'Header 1\'.",\n        "type": "string"\n    },\n    "Header 3": {\n        "description": "Here is a brief description of the specified field:\\n\\n\\"Header 3: Sub-subheading, providing detailed information (Third-level header)\\"ALWAYS filter with one or more CONTAINS comparators, and use the OR operator to check ALL other fields.if the value of this field contains a word or phrase that is very similar to a word or phrase in the query, filter for the exact string from the value rather than the query. NEVER filter this field on the value of \'Header 1\'.",\n        "type": "string"\n    }\n}\n}\n```\n\n\n<< Example 1. >>\nUser Query:\nWhat is the admission quota for male candidates from the Northern region for the Military T ...

# %%
chain = load_query_constructor_runnable(
    llm=llm,
    attribute_info=metadata_field_info,
    document_contents=document_content_description,
    examples=examples,
    fix_invalid=True
)

# %%
query = "điểm chuẩn học viện năm 2021"
chain.invoke(({"query": query}))
# Out:
# StructuredQuery(query='điểm chuẩn học viện năm 2021', filter=Operation(operator=<Operator.AND: 'and'>, arguments=[Comparison(comparator=<Comparator.CONTAIN: 'contain'>, attribute='Header 1', value='Admission information for 2021 of the Military Technical Academy'), Operation(operator=<Operator.OR: 'or'>, arguments=[Comparison(comparator=<Comparator.CONTAIN: 'contain'>, attribute='Header 2', value='Admission scores for 2021'), Comparison(comparator=<Comparator.CONTAIN: 'contain'>, attribute='Header 3', value='Cut-off scores for 2021')])]), limit=None)

# %%
sq_retriever = SelfQueryRetriever(
    query_constructor=chain,
    vectorstore=vectorstore,
    verbose=True,
)

# %%
sq_retriever
# Out:
# SelfQueryRetriever(vectorstore=<langchain_community.vectorstores.chroma.Chroma object at 0x7756db8ea2d0>, query_constructor=FewShotPromptTemplate(input_variables=['query'], examples=[{'i': 1, 'user_query': 'What is the admission quota for male candidates from the Northern region for the Military Technical Academy in 2024?', 'structured_request': '{{\n    "query": "admission quota, Military Technical Academy, 2024, male candidates from the Northern region",\n    "filter": "and(contain(\\"Header 1\\", \\"ADMISSION INFORMATION FOR THE MILITARY TECHNICAL ACADEMY IN 2024\\"), or(contain(\\"Header 2\\", \\"Admission quota\\"), contain(\\"Header 3\\", \\"Admission quota\\")))"\n}}'}, {'i': 2, 'user_query': 'What are the admission methods at the Military Technical Academy?', 'structured_request': '{{\n    "query": "admission methods, Military Technical Academy",\n    "filter": "and(contain(\\"Header 1\\", \\"ADMISSION INFORMATION FOR THE MILITARY TECHNICAL ACADEMY IN 2024\\"), or(contain(\\"Header 2\\", \\"Admission methods\\"), contain(\\"Header 3\\", \\"Method 1: Direct admission\\"), contain(\\"Header 3\\", \\"Method 2: Priority admission\\")))"\n}}'}, {'i': 3, 'user_query': 'What was the admission score for the academy in 2023?', 'structured_request': '{{\n    "query": "admission score, 2023",\n    "filter": "and(contain(\\"Header 1\\", \\"Admission information for 2021, 2022, 2023 of the Military Technical Academy\\"), or(contain(\\"Header 2\\", \\"Admission scores for 2021, 2022, 2023\\"), contain(\\"Header 2\\", \\"Scores for 2023 of the academy\\"), contain(\\"Header 2\\", \\"Cut-off scores for 2023\\")))"\n}}'}], example_prompt=PromptTemplate(input_variables=['i', 'structured_request', 'user_query'], template='<< Example {i}. >>\nUser Query:\n{user_query}\n\nStructured Request:\n```json\n{structured_request}\n```\n'), suffix='<< Example 4. >>\nUser Query:\n{query}\n\nStructured Request:\n', prefix='Your goal is to structure the user\'s query to match the request schema provided below.\n\n<< Structured Request Schema >>\nWhen responding use a markdown code snippet with a JSON object formatted in the following schema:\n\n```json\n{{\n    "query": string \\ text string to compare to document contents\n    "filter": string \\ logical condition statement for filtering documents\n}}\n```\n\nThe query string should contain only text that is expected to match the contents of documents. Any conditions in the filter should not be mentioned in the query as well.\n\nA logical condition statement is composed of one or more comparison and logical operation statements.\n\nA comparison statement takes the form: `comp(attr, val)`:\n- `comp` (eq | ne | gt | gte | lt | lte | contain | like | in | nin): comparator\n- `attr` (string):  name of attribute to apply the comparison to\n- `val` (string): is the comparison value\n\nA logical operation statement takes the form `op(statement1, statement2, ...)`:\n- `op` (and | or | not): logical operator\n- `statement1`, `statement2`, ... (comparison statements or logical operation statements): one or more statements to apply the operation to\n\nMake sure that you only use the comparators and logical operators listed above and no others.\nMake sure that filters only refer to attributes that exist in the data source.\nMake sure that filters only use the attributed names with its function names if there are functions applied on them.\nMake sure that filters only use format `YYYY-MM-DD` when handling date data typed values.\nMake sure that filters take into account the descriptions of attributes and only make comparisons that are feasible given the type of data being stored.\nMake sure that filters are only used as needed. If there are no filters that should be applied return "NO_FILTER" for the filter value.\n\n<< Data Source >>\n```json\n{{\n    "content": "The document contains introductory information about the admissions details of the Military Technical Academy.",\n    "attributes": {{\n    "Header 1": ...
# | ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x7756d939d580>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x7756d939e000>, model_name='llama3-70b-8192', temperature=0.1, groq_api_key=SecretStr('**********'))
# | StructuredQueryOutputParser(ast_parse=<function StructuredQueryOutputParser.from_components.<locals>.ast_parse at 0x7756e3a837e0>), structured_query_translator=<langchain.retrievers.self_query.chroma.ChromaTranslator object at 0x7756e2d966f0>, verbose=True)

# %%
sq_qa = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=sq_retriever,
    return_source_documents=True
)

# %%
query = "chỉ tiêu tuyển sinh của học viện năm 2023"
response = sq_qa({"query": query})
print(response)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 2
#       1 query = "chỉ tiêu tuyển sinh của học viện năm 2023"
# ----> 2 response = sq_qa({"query": query})
#       3 print(response)
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain_core/_api/deprecation.py:180, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     178     warned = True
#     179     emit_warning()
# --> 180 return wrapped(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain/chains/base.py:378, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     346 """Execute the chain.
#     347
#     348 Args:
#    (...)
#     369         `Chain.output_keys`.
#     370 """
#     371 config = {
#     372     "callbacks": callbacks,
#     373     "tags": tags,
#     374     "metadata": metadata,
#     375     "run_name": run_name,
#     376 }
# --> 378 return self.invoke(
#     379     inputs,
#     380     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     381     return_only_outputs=return_only_outputs,
#     382     include_run_info=include_run_info,
#     383 )
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain/chains/base.py:163, in Chain.invoke(self, input, config, **kwargs)
#     161 except BaseException as e:
#     162     run_manager.on_chain_error(e)
# --> 163     raise e
#     164 run_manager.on_chain_end(outputs)
#     166 if include_run_info:
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain/chains/base.py:153, in Chain.invoke(self, input, config, **kwargs)
#     150 try:
#     151     self._validate_inputs(inputs)
#     152     outputs = (
# --> 153         self._call(inputs, run_manager=run_manager)
#     154         if new_arg_supported
#     155         else self._call(inputs)
#     156     )
#     158     final_outputs: Dict[str, Any] = self.prep_outputs(
#     159         inputs, outputs, return_only_outputs
#     160     )
#     161 except BaseException as e:
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain/chains/retrieval_qa/base.py:142, in BaseRetrievalQA._call(self, inputs, run_manager)
#     138 accepts_run_manager = (
#     139     "run_manager" in inspect.signature(self._get_docs).parameters
#     140 )
#     141 if accepts_run_manager:
# --> 142     docs = self._get_docs(question, run_manager=_run_manager)
#     143 else:
#     144     docs = self._get_docs(question)  # type: ignore[call-arg]
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain/chains/retrieval_qa/base.py:254, in RetrievalQA._get_docs(self, question, run_manager)
#     247 def _get_docs(
#     248     self,
#     249     question: str,
#     250     *,
#     251     run_manager: CallbackManagerForChainRun,
#     252 ) -> List[Document]:
#     253     """Get docs."""
# --> 254     return self.retriever.invoke(
#     255         question, config={"callbacks": run_manager.get_child()}
#     256     )
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain_core/retrievers.py:253, in BaseRetriever.invoke(self, input, config, **kwargs)
#     251 except Exception as e:
#     252     run_manager.on_retriever_error(e)
# --> 253     raise e
#     254 else:
#     255     run_manager.on_retriever_end(
#     256         result,
#     257     )
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain_core/retrievers.py:246, in BaseRetriever.invoke(self, input, config, **kwargs)
#     244 _kwargs = kwargs if self._expects_other_args else {}
#     245 if self._new_arg_supported:
# --> 246     result = self._get_relevant_documents(
#     247         input, run_manager=run_manager, **_kwargs
#     248     )
#     249 else:
#     250     result = self._get_relevant_documents(input, **_kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain/retrievers/self_query/base.py:222, in SelfQueryRetriever._get_relevant_documents(self, query, run_manager)
#     220 if self.verbose:
#     221     logger.info(f"Generated Query: {structured_query}")
# --> 222 new_query, search_kwargs = self._prepare_query(query, structured_query)
#     223 docs = self._get_docs_with_query(new_query, search_kwargs)
#     224 return docs
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain/retrievers/self_query/base.py:184, in SelfQueryRetriever._prepare_query(self, query, structured_query)
#     181 def _prepare_query(
#     182     self, query: str, structured_query: StructuredQuery
#     183 ) -> Tuple[str, Dict[str, Any]]:
# --> 184     new_query, new_kwargs = self.structured_query_translator.visit_structured_query(
#     185         structured_query
#     186     )
#     187     if structured_query.limit is not None:
#     188         new_kwargs["k"] = structured_query.limit
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain/retrievers/self_query/chroma.py:49, in ChromaTranslator.visit_structured_query(self, structured_query)
#      47     kwargs = {}
#      48 else:
# ---> 49     kwargs = {"filter": structured_query.filter.accept(self)}
#      50 return structured_query.query, kwargs
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain_core/structured_query.py:82, in Expr.accept(self, visitor)
#      73 def accept(self, visitor: Visitor) -> Any:
#      74     """Accept a visitor.
#      75
#      76     Args:
#    (...)
#      80         result of visiting.
#      81     """
# ---> 82     return getattr(visitor, f"visit_{_to_snake_case(self.__class__.__name__)}")(
#      83         self
#      84     )
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain/retrievers/self_query/chroma.py:33, in ChromaTranslator.visit_operation(self, operation)
#      32 def visit_operation(self, operation: Operation) -> Dict:
# ---> 33     args = [arg.accept(self) for arg in operation.arguments]
#      34     return {self._format_func(operation.operator): args}
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain_core/structured_query.py:82, in Expr.accept(self, visitor)
#      73 def accept(self, visitor: Visitor) -> Any:
#      74     """Accept a visitor.
#      75
#      76     Args:
#    (...)
#      80         result of visiting.
#      81     """
# ---> 82     return getattr(visitor, f"visit_{_to_snake_case(self.__class__.__name__)}")(
#      83         self
#      84     )
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain/retrievers/self_query/chroma.py:39, in ChromaTranslator.visit_comparison(self, comparison)
#      36 def visit_comparison(self, comparison: Comparison) -> Dict:
#      37     return {
#      38         comparison.attribute: {
# ---> 39             self._format_func(comparison.comparator): comparison.value
#      40         }
#      41     }
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain/retrievers/self_query/chroma.py:29, in ChromaTranslator._format_func(self, func)
#      28 def _format_func(self, func: Union[Operator, Comparator]) -> str:
# ---> 29     self._validate_func(func)
#      30     return f"${func.value}"
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain_core/structured_query.py:29, in Visitor._validate_func(self, func)
#      27 if isinstance(func, Comparator) and self.allowed_comparators is not None:
#      28     if func not in self.allowed_comparators:
# ---> 29         raise ValueError(
#      30             f"Received disallowed comparator {func}. Allowed "
#      31             f"comparators are {self.allowed_comparators}"
#      32         )
#
# ValueError: Received disallowed comparator Comparator.CONTAIN. Allowed comparators are [<Comparator.EQ: 'eq'>, <Comparator.NE: 'ne'>, <Comparator.GT: 'gt'>, <Comparator.GTE: 'gte'>, <Comparator.LT: 'lt'>, <Comparator.LTE: 'lte'>]
