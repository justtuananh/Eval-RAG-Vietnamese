# %%
# %pip install --upgrade --quiet  lark qdrant-client

# %%
from langchain_community.vectorstores import Qdrant
from langchain_core.documents import Document
from langchain_community.embeddings.huggingface import HuggingFaceEmbeddings
from langchain_groq import ChatGroq
from langchain_qdrant import QdrantVectorStore
from qdrant_client import QdrantClient
from qdrant_client.http.models import Distance, VectorParams
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.document_loaders import TextLoader
from langchain.text_splitter import MarkdownHeaderTextSplitter
from langchain.retrievers.self_query.base import SelfQueryRetriever
from langchain.text_splitter import RecursiveCharacterTextSplitter, CharacterTextSplitter
from langchain.document_loaders import TextLoader
from langchain.retrievers import ParentDocumentRetriever
from langchain.storage import InMemoryStore
from langchain.docstore.document import Document
from typing import List, Dict
from langchain.chains import RetrievalQA
import os

HF_EMBEDDING = HuggingFaceEmbeddings(model_name="keepitreal/vietnamese-sbert")
llm = ChatGroq(model_name="llama3-70b-8192", temperature=0.1,api_key= os.getenv('llm_api_1'))


# Function to load and chunk data from a folder
def load_and_chunk_data(data_path):
    docs = []
    # Load all .txt files from the specified folder
    for filename in os.listdir(data_path):
        if filename.endswith('.txt'):
            file_path = os.path.join(data_path, filename)
            loader = TextLoader(file_path, encoding='utf-8')
            docs.extend(loader.load())

    # Define headers to split on for Markdown splitting
    headers_to_split_on = [
        ("#", "Header 1"),
        ("##", "Header 2"),
        ("###", "Header 3"),
    ]

    # Initialize Markdown splitter
    markdown_splitter = MarkdownHeaderTextSplitter(
        headers_to_split_on=headers_to_split_on, strip_headers=False
    )

    chunk_size = 512
    chunk_overlap = 0

    # Initialize character-based splitter
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size, chunk_overlap=chunk_overlap
    )

    chunked_docs = []

    # Process each document
    for doc in docs:
        # Split document by Markdown headers
        md_header_splits = markdown_splitter.split_text(doc.page_content)

        # Further split the Markdown header splits into smaller chunks
        chunked_docs.extend(text_splitter.split_documents(md_header_splits))

    return chunked_docs


data_path = '/home/justtuananh/AI4TUAN/DOAN2024/eval_rag_vietnamese/thongtintuyensinh'
chunked_data = load_and_chunk_data(data_path)


vectorstore = Qdrant.from_documents(
    chunked_data,
    HF_EMBEDDING,
    location=":memory:",  # Local mode with in-memory storage only
    collection_name="tintuyensinh",
)
# Out:
# /home/justtuananh/miniconda3/lib/python3.12/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /home/justtuananh/miniconda3/lib/python3.12/site-packages/torch/cuda/__init__.py:118: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# /home/justtuananh/miniconda3/lib/python3.12/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
retriever = vectorstore.as_retriever(search_type="mmr", search_kwargs={"k": 20})
results = retriever.invoke("năm 2024 học viện lấy bao nhiêu chỉ tiêu nữ")
for result in results: 
    print(result.page_content)
# Out:
# ## 4\.Chỉ tiêu tuyển sinh
# Thực hiện theo Quyết định của Bộ Quốc phòng giao. Chỉ tiêu tuyển sinh được xác định theo giới tính (thí sinh nam, thí sinh nữ) và vùng, miền (miền Bắc được tính từ Quảng Bình trở ra, miền Nam được tính từ Quảng Trị trở vào). Chỉ tiêu tuyển sinh năm 2024 sẽ được Học viện thông báo chi tiết sau khi Bộ Quốc phòng giao chỉ tiêu chính thức. Các đối tượng tuyển sinh gồm:
# Đối tượng tuyển sinh: Đào tạo kỹ sư quân sự (Chỉ huy, quản lý kỹ thuật)
# Mã trường: KQH
# Mã ngành: 7860220
# \- Thí sinh đạt học lực Giỏi, hạnh kiểm Tốt năm lớp 10, lớp 11 và học kỳ 1 lớp 12 và có kết quả điểm bài thi đánh giá năng lực quốc tế SAT từ 1.068 điểm trở lên hoặc ACT từ 18 điểm trở lên (chứng chỉ còn thời hạn sử dụng đến thời điểm xét tuyển), tốt nghiệp THPT năm 2024.
# Một là, Học viện là môi trường tốt để các em phát huy được năng lực bản thân, được học tập để khám phá và làm chủ các công nghệ kỹ thuật tiên tiến được ứng dụng trong quân sự như: Trí tuệ nhân tạo, khoa học máy tính, công nghệ rô bốt, điện tử-viễn thông, kỹ thuật điều khiển tự động và tự động hoá, kỹ thuật ra đa-dẫn đường, kỹ thuật cơ khí động lực, kỹ thuật xây dựng, công nghệ hoá học, môi trường …
# Phòng SCH Trung đoàn Tên lửa phòng không
# Phòng SCH Trung đoàn Ra đa phòng không
# Phòng học chuyên dùng CHQLKT quân chủng
# Phòng học chuyên dùng CHQLKT Công Binh
# PHCD Thông tin và Cơ yếu
# Phòng học chuyên dùng BCHT
# PTN Vật lý ĐC I
# PTN Vật lý ĐC II
# PTN Vật lý Kỹ thuật
# PTN Hóa phân tích
# Kỹ thuật Môi trường
# PTN Nguồn điện
# PTN Đại cương
# PTN Vật liệu quân sự
# PTN Công nghệ hóa học
# PTN Hóa lý
# PTN Vô cơ
# PTN Hữu cơ
# PTN Polime-Composit
# PTN Phòng hóa
# Phòng học chuyên dụng chuyên ngành phòng hóa
# Kho phòng hóa
# \- Phương thức 5: Xét tuyển theo kết quả của kỳ thi tốt nghiệp THPT năm 2024. Thực hiện xét cho số chỉ tiêu còn lại.
# ## 11\. Chế độ, tiêu chuẩn của học viên
# ------------------------------------
# \- Học viên vào đào tạo kỹ sư quân sự tại Học viện KTQS được Bộ Quốc phòng phân công ngành học; được bảo đảm mọi điều kiện về ăn, ở, quần, áo, dày, dép và quân trang cá nhân; được bảo đảm về cơ sở vật chất, trang thiết bị, đồ dùng phục vụ cho học tập; được hưởng chế độ nghỉ hè, nghỉ tết theo quy định
# Chỉ tiêu: 540
# Tổ hợp xét tuyển: A00 và A01
# Thí sinh có thường trú phía Bắc:
# Tổng chỉ tiêu: 351
# Thí sinh nam: 335 chỉ tiêu
# Thí sinh nữ: 16 chỉ tiêu
# Thí sinh có thường trú phía Nam:
# Tổng chỉ tiêu: 189
# Thí sinh nam: 181 chỉ tiêu
# Thí sinh nữ: 8 chỉ tiêu
# **_Trong số chỉ tiêu được giao, Học viện KTQS tuyển khoảng 20% chỉ tiêu đào tạo nước ngoài, và khoảng 30 chỉ tiêu đào tạo kỹ sư chất lượng cao của 02 chuyên ngành: An ninh hệ thống thông tin, Thông tin._**
# ## II. MỘT SỐ ĐIỂM MỚI TRONG CÔNG TÁC TUYỂN SINH TẠI HỌC VIỆN KỸ THUẬT QUÂN SỰ NĂM 2024**
# Thực hiện Đề án “Tổ chức tuyển sinh đại học, cao đẳng quân sự hệ chính quy giai đoạn năm 2023 - 2030 và những năm tiếp theo” của Bộ Quốc phòng, trong kỳ tuyển sinh đại học, cao đẳng năm 2024 của Học viện Kỹ thuật quân sự có một số điểm mới, các em học sinh cần lưu ý một số nội dung như sau:
# Về phương thức tuyển sinh, năm 2024, Học viện Kỹ thuật quân sự tuyển sinh theo các phương thức như sau:
# # THÔNG TIN KỲ TUYỂN SINH CỦA HỌC VIỆN KỸ THUẬT QUÂN SỰ NĂM 2024
# ## 1\. Đối tượng tuyển sinh
# \- Hạ sĩ quan, binh sĩ đang phục vụ tại ngũ theo quy định của pháp luật về nghĩa vụ quân sự, có thời gian phục vụ tại ngũ 12 tháng trở lên, tính đến tháng 4 của năm tuyển sinh; quân nhân chuyên nghiệp, công nhân và viên chức quốc phòng phục vụ trong quân đội đủ 12 tháng trở lên, tính đến tháng 9 của năm tuyển sinh.
# \- Học viện KTQS sử dụng một mã ngành chung để tuyển sinh, cụ thể:
# Tên trường: Học viện Kỹ thuật quân sự
# Mã trường: KQH
# Mã ngành: 7860220
# Tên ngành: Chỉ huy, quản lý kỹ thuật.
# \+ Thí sinh đăng ký xét tuyển học sinh giỏi bậc THPT phải đăng ký dự thi Kỳ thi tốt nghiệp THPT năm 2024 theo quy định của Bộ GD&ĐT, đăng ký nguyện vọng 1 vào Học viện KTQS và phải nộp hồ sơ đăng ký xét tuyển HSG bậc THPT tại Ban TSQS cấp quận, huyện.
# \+ Thời gian: Dự kiến trước ngày 25/6/2024.
# c) Tổ chức xét tuyển học sinh giỏi bậc THPT
# ## 5\. Phương thức tuyển sinh
# --------------------------
# Năm 2024, Học viện KTQS tuyển sinh theo các phương thức:
# \- Phương thức 1: Xét tuyển thẳng.
# \- Phương thức 2: Ưu tiên xét tuyển.
# \- Phương thức 3: Xét tuyển học sinh giỏi bậc THPT.
# Tổng chỉ tiêu của Phương thức 1, 2, 3 không quá 15% tổng chỉ tiêu được giao.
# \- Phương thức 4: Xét tuyển bằng kết quả thi ĐGNL của ĐH Quốc gia Hà Nội và ĐH Quốc gia TP Hồ Chí Minh. Thực hiện xét không quá 20% tổng chỉ tiêu được giao.
# ### 6.2. Đăng ký, thực hiện làm hồ sơ sơ tuyển**
# \- Thời gian sơ tuyển thực hiện theo hướng dẫn của Ban tuyển sinh quân sự Bộ Quốc phòng, năm 2023 thời gian sơ tuyển: Dự kiến từ ngày 25/3/2024 đến ngày 20/5/2024.
# \- Thí sinh là thanh niên ngoài Quân đội đăng ký sơ tuyển tại Ban TSQS cấp huyện (quận, thị xã, thành phố trực thuộc tỉnh, thành phố trực thuộc Trung ương), nơi thí sinh đăng ký thường trú (gọi chung là Ban TSQS cấp huyện).
# ## **2.1. Đối tượng đào tạo trình độ đại học**
# Thực hiện theo quy định của Bộ Quốc phòng. Học viên được học tập, khám phá và làm chủ các công nghệ tiên tiến được ứng dụng trong quân sự. Học viên được bảo đảm mọi mặt về sinh hoạt và đào tạo trong suốt thời gian đào tạo, sau khi tốt nghiệp được Bộ Quốc phòng phân công công tác tại các đơn vị trong toàn quân, thân nhân học viên (bố, mẹ, con) được hưởng chế độ bảo hiểm y tế theo quy định.
# 4. Xét tuyển dựa vào kết quả thi tốt nghiệp THPT theo quy chế của Bộ Giáo dục và Đào tạo.
# Như vậy, so với năm 2023, trong kỳ tuyển sinh đại học năm 2024 Học viện Kỹ thuật quân sựbổ sung phương thức lấy kết quả thi đánh giá năng lực của Đại học Quốc gia Hà Nội và Đại học Quốc gia Thành phố Hồ Chí Minh để xét tuyển. Đây là cơ hộiđể các em có thêm nguyện vọng được xét tuyển vào Học viện Kỹ thuật quân sự để thực hiện ước mơ trở thành người cán bộ kỹ thuật quân đội.
# Phòng học chuyên dùng
# PTN Công nghệ điện tử
# PTN Thiết kế vi mạch
# Xưởng chế thử vi mạch chuyên dụng
# Kho vật tư thiết kế vi mạch chuyên dụng
# PTN Tích hợp vũ khí
# PTN Tự động hóa chỉ huy
# Trường bắn ảo
# Giảng đường chuyên dùng chiến thuật binh chủng hợp thành
# Giảng đường chuyên dùng chiến thuật quân, binh chủng
# Trung tâm Chỉ huy, quản lý kỹ thuật
# Phòng chỉ huy điều hành diễn tập
# Phòng học chuyên dùng CHQL cơ sở sản xuất, dự trữ
# Phòng học chuyên dùng CHQLKT Quân khí
# Phòng chuyên dùng CHQLKT Tăng thiết giáp
# Để được đăng ký xét tuyển vào Học viện Kỹ thuật quân sự, các em học sinh cần làm thủ tục đăng ký sơ tuyển tại Ban Chỉ huy quân sự cấp quận, huyện nơi đăng ký hộ khẩu thường trú, thời gian đăng ký khoảng từ ngày 15/3/2024. Chi tiết về chỉ tiêu đào tạo, quy trình, thủ tục đăng ký sơ tuyển, đăng ký xét tuyển, Học viện sẽ thông báo rộng rãi khi có kế hoạch tuyển sinhcủa Ban Tuyển sinh quân sự Bộ Quốc phòng.
# # Thông tin tuyển sinh năm 2021, 2022, 2023 của học viện kỹ thuật quân sự
# ## 4.1. Phương thức tuyển sinh năm** **2021, 2022, 2023**
# Năm 2021, 2022, 2022 Học viện KTQS tuyển sinh theo phương thức:
# \- Xét tuyển thẳng (XTT), ưu tiên xét tuyển (ƯTXT), xét tuyển HSG bậc THPT (HSG bậc THPT) thực hiện theo quy định của Ban tuyển sinh quân sự Bộ Quốc phòng.
# \- Xét tuyển (XT) trên cơ sở kết quả của Kỳ thi tốt nghiệp Trung học phổ thông (THPT).
# ---
# \- Thí sinh đạt học lực Giỏi, hạnh kiểm Tốt năm lớp 10, lớp 11 và học kỳ 1 lớp 12 và có kết quả điểm ngoại ngữ IELTS 5.5 điểm hoặc TOEFL iBT 55 điểm trở lên (chứng chỉ còn thời hạn sử dụng đến thời điểm xét tuyển), tốt nghiệp THPT năm 2024.
# b) Hồ sơ đăng ký xét tuyển học sinh giỏi bậc THPT
# \- Hồ sơ gồm:
# \+ Phiếu đăng ký xét tuyển HSG THPT (Theo mẫu của Bộ Quốc phòng).
# \+ Giấy tờ minh chứng thuộc diện Ưu tiên xét tuyển (Giấy chứng nhận đạt giải Kỳ thi HSG cấp Quốc gia, giấy chứng nhận đạt giải Cuộc thi Khoa học kỹ thuật cấp Quốc gia).
# \- Địa điểm, thời gian nộp hồ sơ:
# \+ Thí sinh đăng ký ưu tiên xét tuyển phải đăng ký dự thi Kỳ thi tốt nghiệp THPT năm 2023 theo quy định của Bộ GD&ĐT, đăng ký nguyện vọng 1 vào Học viện KTQS và phải nộp hồ sơ đăng ký ưu tiên xét tuyển tại Ban TSQS cấp quận, huyện.
# \+ Thời gian: Dự kiến trước ngày 25/6/2024.

# %% [markdown]
# ### Retrieval

# %%
from langchain.retrievers.self_query.base import SelfQueryRetriever
# add self-query
from langchain.chains.query_constructor.base import (
    get_query_constructor_prompt,
    load_query_constructor_runnable,
    AttributeInfo)
# Cấu hình thông tin metadata
metadata_field_info = [
    AttributeInfo(
        name="Header 1",
        description="""
Đây là tiêu đề cấp cao nhất, thường được sử dụng để giới thiệu tổng quan về chủ đề chính. 
Khi lọc dữ liệu, nếu truy vấn chứa lỗi chính tả hoặc cách viết khác của tên này, bạn nên lọc dựa trên giá trị của trường này thay vì dựa vào tên trong truy vấn.
 Phải kết hợp bộ lọc tiêu đề cấp 1 với các bộ lọc phụ đề sử dụng toán tử AND. 
 Luôn sử dụng một hoặc nhiều bộ lọc like và sử dụng toán tử OR để kiểm tra tất cả các trường khác. 
 Nếu giá trị của trường này chứa từ hoặc cụm từ tương tự như trong truy vấn, hãy lọc theo chuỗi chính xác từ giá trị thay vì từ truy vấn.
""",
        type="string",
    ),
    AttributeInfo(
        name="Header 2",
        description="""
Đây là tiêu đề cấp hai, được sử dụng để chia nhỏ nội dung thành các phần nhỏ hơn. 
Luôn luôn sử dụng một hoặc nhiều bộ lọc like và sử dụng toán tử OR để kiểm tra tất cả các trường khác.
Nếu giá trị của trường này chứa từ hoặc cụm từ tương tự như trong truy vấn, hãy lọc theo chuỗi chính xác từ giá trị thay vì từ truy vấn.
Không bao giờ lọc trường này dựa trên giá trị của trường 'Header 1'.
""",
        type="string",
    ),
    AttributeInfo(
        name="Header 3",
        description="""
Đây là tiêu đề cấp ba, cung cấp thông tin chi tiết hơn. 
Luôn luôn sử dụng một hoặc nhiều bộ lọc like và sử dụng toán tử OR để kiểm tra tất cả các trường khác. 
Nếu giá trị của trường này chứa từ hoặc cụm từ tương tự như trong truy vấn, hãy lọc theo chuỗi chính xác từ giá trị thay vì từ truy vấn. 
Không bao giờ lọc trường này dựa trên giá trị của trường 'Header 1'
""",
        type="string",
    )
]


document_content_description = "Tài liệu nói về thông tin tuyển sinh của học viện kỹ thuật quân sự trong năm nay và các năm gần đây."

# Tạo SelfQueryRetriever
retriever = SelfQueryRetriever.from_llm(
    llm, vectorstore, document_content_description, metadata_field_info, verbose=True, enable_limit=True,
)

# %%
examples = [
    (
        " Chỉ tiêu tuyển sinh của học viện năm 2024",
        {"query": "chỉ tiêu tuyển sinh, học viên năm 2024",
         "filter": 'and(like("Header 1", "THÔNG TIN KỲ TUYỂN SINH CỦA HỌC VIỆN KỸ THUẬT QUÂN SỰ NĂM 2024"), or(like("Header 2", "Chỉ tiêu tuyển sinh"), '
                   'like("Header 3", "Chỉ tiêu tuyển sinh")))'}
    ),
    (
        "Các phương thức xét tuyển tại học viện kỹ thuật quân sự",
        {"query": "phương thức xét tuyển, học viện kỹ thuật quân sự",
         "filter": 'and(like("Header 1", "THÔNG TIN KỲ TUYỂN SINH CỦA HỌC VIỆN KỸ THUẬT QUÂN SỰ NĂM 2024"), or(like("Header 2", "Tổ chức xét tuyển"), '
                   'like("Header 3", "Phương thức 1: Xét tuyển thẳng**")))'}
    ),
    (
        "Điểm trúng tuyển năm 2023 của học viện",
        {"query": "trúng tuyển, 2023",
         "filter": 'and(like("Header 1", "Thông tin tuyển sinh năm 2021, 2022, 2023 của học viện kỹ thuật quân sự"), or(like("Header 2", "4.2. Điểm trúng tuyển năm 2021, 2022, 2023**"), '
                   'like("Header 3", "4.2. Điểm trúng tuyển năm 2021, 2022, 2023**")))'}
    )
]

# %%
examples = [
    (
        "Admission quota of the academy for 2024",
        {
            "query": "admission quota, academy, 2024",
            "filter": 'and(like("Header 1", "ADMISSION INFORMATION OF MILITARY TECHNICAL ACADEMY IN 2024"), '
                      'or(like("Header 2", "Admission quota"), like("Header 3", "Admission quota")))'
        }
    ),
    (
        "Admission methods at the Military Technical Academy",
        {
            "query": "admission methods, military technical academy",
            "filter": 'and(like("Header 1", "ADMISSION INFORMATION OF MILITARY TECHNICAL ACADEMY IN 2024"), '
                      'or(like("Header 2", "Admission process"), like("Header 3", "Method 1: Direct admission**")))'
        }
    ),
    (
        "Admission scores for 2023 of the academy",
        {
            "query": "admission scores, 2023",
            "filter": 'and(like("Header 1", "Admission information of Military Technical Academy for 2021, 2022, 2023"), '
                      'or(like("Header 2", "4.2. Admission scores for 2021, 2022, 2023**"), '
                      'like("Header 3", "4.2. Admission scores for 2021, 2022, 2023**")))'
        }
    )
]

# %%
prompt = get_query_constructor_prompt(
    document_content_description,
    metadata_field_info,
    examples=examples
)
query = "Tôi vào học viện rôi thì phải đóng bao nhiêu tiền học phí vậy?"
print(prompt.format(query="{query}"))

# %%
chain = load_query_constructor_runnable(
    llm=llm,
    attribute_info=metadata_field_info,
    document_contents=document_content_description,
    examples=examples,
    fix_invalid=True
)

# %%
query = "chỉ tiêu tuyển sinh của học viện năm 2024"
chain.invoke(({"query": query}))

# %%
from langchain.retrievers import SelfQueryRetriever

retriever = SelfQueryRetriever(
    query_constructor=chain, vectorstore=vectorstore, verbose=True
)

# %%
results = retriever.invoke(
    "Chỉ tiêu tuyển sinh của học viện năm 2024"
)
for res in results:
    print(res.page_content)
    print("\n" + "-" * 20 + "\n")

# %%
sq_retriever = SelfQueryRetriever(
    query_constructor=chain,
    vectorstore=vectorstore,
    verbose=True,
)
sq_qa = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=sq_retriever,
    return_source_documents=True
)

# %%
query = "chỉ tiêu tuyển sinh của học viện năm 2023"
response = sq_qa({"query": query})
print(response)

# %%
sq_retriever = SelfQueryRetriever(
    query_constructor=chain,
    vectorstore=vectorstore,
    verbose=True,
)

# %%
# không add thêm ví dụ vào 
sq_retriever.invoke("học khối nào thi được vào học viện")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 # không add thêm ví dụ vào
# ----> 2 sq_retriever.invoke("học khối nào thi được vào học viện")
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain_core/retrievers.py:253, in BaseRetriever.invoke(self, input, config, **kwargs)
#     251 except Exception as e:
#     252     run_manager.on_retriever_error(e)
# --> 253     raise e
#     254 else:
#     255     run_manager.on_retriever_end(
#     256         result,
#     257     )
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain_core/retrievers.py:246, in BaseRetriever.invoke(self, input, config, **kwargs)
#     244 _kwargs = kwargs if self._expects_other_args else {}
#     245 if self._new_arg_supported:
# --> 246     result = self._get_relevant_documents(
#     247         input, run_manager=run_manager, **_kwargs
#     248     )
#     249 else:
#     250     result = self._get_relevant_documents(input, **_kwargs)
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain/retrievers/self_query/base.py:223, in SelfQueryRetriever._get_relevant_documents(self, query, run_manager)
#     221     logger.info(f"Generated Query: {structured_query}")
#     222 new_query, search_kwargs = self._prepare_query(query, structured_query)
# --> 223 docs = self._get_docs_with_query(new_query, search_kwargs)
#     224 return docs
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain/retrievers/self_query/base.py:197, in SelfQueryRetriever._get_docs_with_query(self, query, search_kwargs)
#     194 def _get_docs_with_query(
#     195     self, query: str, search_kwargs: Dict[str, Any]
#     196 ) -> List[Document]:
# --> 197     docs = self.vectorstore.search(query, self.search_type, **search_kwargs)
#     198     return docs
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain_core/vectorstores/base.py:337, in VectorStore.search(self, query, search_type, **kwargs)
#     321 """Return docs most similar to query using a specified search type.
#     322
#     323 Args:
#    (...)
#     334         "mmr", or "similarity_score_threshold".
#     335 """
#     336 if search_type == "similarity":
# --> 337     return self.similarity_search(query, **kwargs)
#     338 elif search_type == "similarity_score_threshold":
#     339     docs_and_similarities = self.similarity_search_with_relevance_scores(
#     340         query, **kwargs
#     341     )
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain_community/vectorstores/qdrant.py:286, in Qdrant.similarity_search(self, query, k, filter, search_params, offset, score_threshold, consistency, **kwargs)
#     241 def similarity_search(
#     242     self,
#     243     query: str,
#    (...)
#     250     **kwargs: Any,
#     251 ) -> List[Document]:
#     252     """Return docs most similar to query.
#     253
#     254     Args:
#    (...)
#     284         List of Documents most similar to the query.
#     285     """
# --> 286     results = self.similarity_search_with_score(
#     287         query,
#     288         k,
#     289         filter=filter,
#     290         search_params=search_params,
#     291         offset=offset,
#     292         score_threshold=score_threshold,
#     293         consistency=consistency,
#     294         **kwargs,
#     295     )
#     296     return list(map(itemgetter(0), results))
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain_community/vectorstores/qdrant.py:362, in Qdrant.similarity_search_with_score(self, query, k, filter, search_params, offset, score_threshold, consistency, **kwargs)
#     317 def similarity_search_with_score(
#     318     self,
#     319     query: str,
#    (...)
#     326     **kwargs: Any,
#     327 ) -> List[Tuple[Document, float]]:
#     328     """Return docs most similar to query.
#     329
#     330     Args:
#    (...)
#     360         List of documents most similar to the query text and distance for each.
#     361     """
# --> 362     return self.similarity_search_with_score_by_vector(
#     363         self._embed_query(query),
#     364         k,
#     365         filter=filter,
#     366         search_params=search_params,
#     367         offset=offset,
#     368         score_threshold=score_threshold,
#     369         consistency=consistency,
#     370         **kwargs,
#     371     )
#
# File ~/miniconda3/lib/python3.12/site-packages/langchain_community/vectorstores/qdrant.py:608, in Qdrant.similarity_search_with_score_by_vector(self, embedding, k, filter, search_params, offset, score_threshold, consistency, **kwargs)
#     605 if self.vector_name is not None:
#     606     query_vector = (self.vector_name, embedding)  # type: ignore[assignment]
# --> 608 results = self.client.search(
#     609     collection_name=self.collection_name,
#     610     query_vector=query_vector,
#     611     query_filter=qdrant_filter,
#     612     search_params=search_params,
#     613     limit=k,
#     614     offset=offset,
#     615     with_payload=True,
#     616     with_vectors=False,  # Langchain does not expect vectors to be returned
#     617     score_threshold=score_threshold,
#     618     consistency=consistency,
#     619     **kwargs,
#     620 )
#     621 return [
#     622     (
#     623         self._document_from_scored_point(
#    (...)
#     631     for result in results
#     632 ]
#
# File ~/miniconda3/lib/python3.12/site-packages/qdrant_client/qdrant_client.py:387, in QdrantClient.search(self, collection_name, query_vector, query_filter, search_params, limit, offset, with_payload, with_vectors, score_threshold, append_payload, consistency, shard_key_selector, timeout, **kwargs)
#     316 """Search for closest vectors in collection taking into account filtering conditions
#     317
#     318 Args:
#    (...)
#     383     List of found close points with similarity scores.
#     384 """
#     385 assert len(kwargs) == 0, f"Unknown arguments: {list(kwargs.keys())}"
# --> 387 return self._client.search(
#     388     collection_name=collection_name,
#     389     query_vector=query_vector,
#     390     query_filter=query_filter,
#     391     search_params=search_params,
#     392     limit=limit,
#     393     offset=offset,
#     394     with_payload=with_payload,
#     395     with_vectors=with_vectors,
#     396     score_threshold=score_threshold,
#     397     append_payload=append_payload,
#     398     consistency=consistency,
#     399     shard_key_selector=shard_key_selector,
#     400     timeout=timeout,
#     401     **kwargs,
#     402 )
#
# File ~/miniconda3/lib/python3.12/site-packages/qdrant_client/local/qdrant_local.py:204, in QdrantLocal.search(self, collection_name, query_vector, query_filter, search_params, limit, offset, with_payload, with_vectors, score_threshold, **kwargs)
#     184 def search(
#     185     self,
#     186     collection_name: str,
#    (...)
#     201     **kwargs: Any,
#     202 ) -> List[types.ScoredPoint]:
#     203     collection = self._get_collection(collection_name)
# --> 204     return collection.search(
#     205         query_vector=query_vector,
#     206         query_filter=query_filter,
#     207         limit=limit,
#     208         offset=offset,
#     209         with_payload=with_payload,
#     210         with_vectors=with_vectors,
#     211         score_threshold=score_threshold,
#     212     )
#
# File ~/miniconda3/lib/python3.12/site-packages/qdrant_client/local/local_collection.py:517, in LocalCollection.search(self, query_vector, query_filter, limit, offset, with_payload, with_vectors, score_threshold)
#     493 def search(
#     494     self,
#     495     query_vector: Union[
#    (...)
#     515     score_threshold: Optional[float] = None,
#     516 ) -> List[models.ScoredPoint]:
# --> 517     payload_mask = calculate_payload_mask(
#     518         payloads=self.payload,
#     519         payload_filter=query_filter,
#     520         ids_inv=self.ids_inv,
#     521     )
#     522     name, query_vector = self._resolve_query_vector_name(query_vector)
#     524     result: List[models.ScoredPoint] = []
#
# File ~/miniconda3/lib/python3.12/site-packages/qdrant_client/local/payload_filters.py:287, in calculate_payload_mask(payloads, payload_filter, ids_inv)
#     285 mask = np.zeros(len(payloads), dtype=bool)
#     286 for i, payload in enumerate(payloads):
# --> 287     if check_filter(payload_filter, payload, ids_inv[i]):
#     288         mask[i] = True
#     289 return mask
#
# File ~/miniconda3/lib/python3.12/site-packages/qdrant_client/local/payload_filters.py:264, in check_filter(payload_filter, payload, point_id)
#     262         return False
#     263 if payload_filter.should is not None:
# --> 264     if not check_should(payload_filter.should, payload, point_id):
#     265         return False
#     266 if payload_filter.min_should is not None:
#
# File ~/miniconda3/lib/python3.12/site-packages/qdrant_client/local/payload_filters.py:240, in check_should(conditions, payload, point_id)
#     237 def check_should(
#     238     conditions: List[models.Condition], payload: dict, point_id: models.ExtendedPointId
#     239 ) -> bool:
# --> 240     return any(check_condition(condition, payload, point_id) for condition in conditions)
#
# File ~/miniconda3/lib/python3.12/site-packages/qdrant_client/local/payload_filters.py:240, in <genexpr>(.0)
#     237 def check_should(
#     238     conditions: List[models.Condition], payload: dict, point_id: models.ExtendedPointId
#     239 ) -> bool:
# --> 240     return any(check_condition(condition, payload, point_id) for condition in conditions)
#
# File ~/miniconda3/lib/python3.12/site-packages/qdrant_client/local/payload_filters.py:189, in check_condition(condition, payload, point_id)
#     187         return True
#     188 elif isinstance(condition, models.FieldCondition):
# --> 189     values = value_by_key(payload, condition.key)
#     190     if condition.match is not None:
#     191         if values is None:
#
# File ~/miniconda3/lib/python3.12/site-packages/qdrant_client/local/payload_value_extractor.py:28, in value_by_key(payload, key, flat)
#      10 def value_by_key(payload: dict, key: str, flat: bool = True) -> Optional[List[Any]]:
#      11     """
#      12     Get value from payload by key.
#      13     Args:
#    (...)
#      26         List of values or None if key not found.
#      27     """
# ---> 28     keys = parse_json_path(key)
#      29     result = []
#      31     def _get_value(data: Any, k_list: List[JsonPathItem]) -> None:
#
# File ~/miniconda3/lib/python3.12/site-packages/qdrant_client/local/json_path_parser.py:57, in parse_json_path(key)
#      55 brackets_chunks, rest = match_brackets(rest)
#      56 keys.extend(brackets_chunks)
# ---> 57 json_path = trunk_sep(rest)
#      58 if not json_path:
#      59     return keys
#
# File ~/miniconda3/lib/python3.12/site-packages/qdrant_client/local/json_path_parser.py:78, in trunk_sep(path)
#      76     return path
#      77 else:
# ---> 78     raise ValueError("Invalid path")
#
# ValueError: Invalid path
